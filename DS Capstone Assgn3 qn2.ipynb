# %% [markdown]
# #Load List of postal codes except Borough ="Not assigned" using pandas df

# %%
import pandas as pd

# %%
url='https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
df=pd.read_html(url,header=0)[0]
df.head()
# Out:
#   Postcode           Borough     Neighbourhood
# 0      M1A      Not assigned      Not assigned
# 1      M2A      Not assigned      Not assigned
# 2      M3A        North York         Parkwoods
# 3      M4A        North York  Victoria Village
# 4      M5A  Downtown Toronto      Harbourfront

# %%
df.drop(df[df.Borough =='Not assigned'].index, inplace=True)
df.head()
# Out:
#   Postcode           Borough     Neighbourhood
# 2      M3A        North York         Parkwoods
# 3      M4A        North York  Victoria Village
# 4      M5A  Downtown Toronto      Harbourfront
# 5      M5A  Downtown Toronto       Regent Park
# 6      M6A        North York  Lawrence Heights

# %% [markdown]
# #Get the latitude and Longitude for the above df using pandas

# %%
df1 = pd.read_csv("F:/Downloads/Geospatial_Coordinates.csv" )
df1.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %% [markdown]
# #Concatenate two dataframes

# %%
df2 = pd.concat([df,df1],axis =1)

# %%
df2.drop('Postal Code',axis =1,inplace=True)
df2.head()
# Out:
#   Postcode           Borough     Neighbourhood   Latitude  Longitude
# 0      NaN               NaN               NaN  43.806686 -79.194353
# 1      NaN               NaN               NaN  43.784535 -79.160497
# 2      M3A        North York         Parkwoods  43.763573 -79.188711
# 3      M4A        North York  Victoria Village  43.770992 -79.216917
# 4      M5A  Downtown Toronto      Harbourfront  43.773136 -79.239476

# %% [markdown]
# #Drop Nan

# %%
df2.dropna()
# Out:
#     Postcode           Borough            Neighbourhood   Latitude  Longitude
# 2        M3A        North York                Parkwoods  43.763573 -79.188711
# 3        M4A        North York         Victoria Village  43.770992 -79.216917
# 4        M5A  Downtown Toronto             Harbourfront  43.773136 -79.239476
# 5        M5A  Downtown Toronto              Regent Park  43.744734 -79.239476
# 6        M6A        North York         Lawrence Heights  43.727929 -79.262029
# 7        M6A        North York           Lawrence Manor  43.711112 -79.284577
# 8        M7A      Queen's Park             Not assigned  43.716316 -79.239476
# 10       M9A         Etobicoke         Islington Avenue  43.757410 -79.273304
# 11       M1B       Scarborough                    Rouge  43.750072 -79.295849
# 12       M1B       Scarborough                  Malvern  43.794200 -79.262029
# 14       M3B        North York          Don Mills North  43.815252 -79.284577
# 15       M4B         East York         Woodbine Gardens  43.799525 -79.318389
# 16       M4B         East York            Parkview Hill  43.836125 -79.205636
# 17       M5B  Downtown Toronto                  Ryerson  43.803762 -79.363452
# 18       M5B  Downtown Toronto          Garden District  43.778517 -79.346556
# 19       M6B        North York                Glencairn  43.786947 -79.385975
# 22       M9B         Etobicoke               Cloverdale  43.770120 -79.408493
# 23       M9B         Etobicoke                Islington  43.752758 -79.400049
# 24       M9B         Etobicoke             Martin Grove  43.782736 -79.442259
# 25       M9B         Etobicoke         Princess Gardens  43.753259 -79.329656
# 26       M9B         Etobicoke          West Deane Park  43.745906 -79.352188
# 27       M1C       Scarborough           Highland Creek  43.725900 -79.340923
# 28       M1C       Scarborough               Rouge Hill  43.754328 -79.442259
# 29       M1C       Scarborough               Port Union  43.767980 -79.487262
# 31       M3C        North York          Flemingdon Park  43.739015 -79.506944
# 32       M3C        North York          Don Mills South  43.728496 -79.495697
# 33       M4C         East York         Woodbine Heights  43.761631 -79.520999
# 34       M5C  Downtown Toronto           St. James Town  43.725882 -79.315572
# 35       M6C              York       Humewood-Cedarvale  43.706397 -79.309937
# 38       M9C         Etobicoke        Bloordale Gardens  43.709060 -79.363452
# ..       ...               ...                      ...        ...        ...
# 67       M4H         East York         Thorncliffe Park  43.653206 -79.400049
# 68       M5H  Downtown Toronto                 Adelaide  43.628947 -79.394420
# 69       M5H  Downtown Toronto                     King  43.646435 -79.374846
# 70       M5H  Downtown Toronto                 Richmond  43.648429 -79.382280
# 71       M6H      West Toronto       Dovercourt Village  43.718518 -79.464763
# 72       M6H      West Toronto                 Dufferin  43.709577 -79.445073
# 76       M1J       Scarborough      Scarborough Village  43.669005 -79.442259
# 77       M2J        North York                 Fairview  43.647927 -79.419750
# 78       M2J        North York               Henry Farm  43.636847 -79.428191
# 79       M2J        North York                   Oriole  43.713756 -79.490074
# 80       M3J        North York           Northwood Park  43.691116 -79.476013
# 81       M3J        North York          York University  43.673185 -79.487262
# 82       M4J         East York             East Toronto  43.661608 -79.464763
# 83       M5J  Downtown Toronto        Harbourfront East  43.648960 -79.456325
# 84       M5J  Downtown Toronto          Toronto Islands  43.651571 -79.484450
# 85       M5J  Downtown Toronto            Union Station  43.662301 -79.389494
# 86       M6J      West Toronto          Little Portugal  43.636966 -79.615819
# 87       M6J      West Toronto                  Trinity  43.662744 -79.321558
# 91       M1K       Scarborough     East Birchmount Park  43.636258 -79.498509
# 92       M1K       Scarborough                  Ionview  43.628841 -79.520999
# 93       M1K       Scarborough             Kennedy Park  43.667856 -79.532242
# 94       M2K        North York          Bayview Village  43.650943 -79.554724
# 95       M3K        North York              CFB Toronto  43.643515 -79.577201
# 96       M3K        North York           Downsview East  43.756303 -79.565963
# 97       M4K      East Toronto        The Danforth West  43.724766 -79.532242
# 98       M4K      East Toronto                Riverdale  43.706876 -79.518188
# 99       M5K  Downtown Toronto          Design Exchange  43.696319 -79.532242
# 100      M5K  Downtown Toronto  Toronto Dominion Centre  43.688905 -79.554724
# 101      M6K      West Toronto                 Brockton  43.739416 -79.588437
# 102      M6K      West Toronto         Exhibition Place  43.706748 -79.594054
#
# [78 rows x 5 columns]

# %%
# !conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

# %%
map_can = folium.Map(location=[latitude, longitude], zoom_start=11)

# add markers to map
for lat, lng, label in zip(df2['Latitude'], df2['Longitude'], df2['Neighborhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_manhattan)  
    
map_can
